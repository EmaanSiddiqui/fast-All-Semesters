# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score, StratifiedShuffleSplit, RepeatedKFold, train_test_split
import math
import statistics

# %% [markdown]
# # DATASET 1
# ## Breast Cancer Dataset

# %%
dataset = pd.read_csv(r"D:\FastSemesters\semester5\ML\lab\breastCancer.csv")
dataset.drop('id',axis=1,inplace=True)
dataset.drop('Unnamed: 32',axis=1,inplace=True)
dataset['diagnosis'] = dataset['diagnosis'].map({'M':1,'B':0})
dataset
# Out:
#      diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0            1        17.99         10.38          122.80     1001.0
# 1            1        20.57         17.77          132.90     1326.0
# 2            1        19.69         21.25          130.00     1203.0
# 3            1        11.42         20.38           77.58      386.1
# 4            1        20.29         14.34          135.10     1297.0
# ..         ...          ...           ...             ...        ...
# 564          1        21.56         22.39          142.00     1479.0
# 565          1        20.13         28.25          131.20     1261.0
# 566          1        16.60         28.08          108.30      858.1
# 567          1        20.60         29.33          140.10     1265.0
# 568          0         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
# 10X10 FOLD CV
array = dataset.values
X = array[:,1:30]
Y = array[:,0]

CV = RepeatedKFold(n_splits = 10, n_repeats = 10, random_state = 1)

# %%
# Decision Tree using gini (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='gini')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.93
# Standard Deviation:  0.03

# %%
# Decision Tree using gini (pruning parameter)
dt = DecisionTreeClassifier( criterion='gini', ccp_alpha = 0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.92
# Standard Deviation:  0.03

# %%
# Decision Tree using Entropy (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='entropy')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.93
# Standard Deviation:  0.03

# %%
# Decision Tree using Entropy (pruning parameter)
dt= DecisionTreeClassifier( criterion='entropy', ccp_alpha= 0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.93
# Standard Deviation:  0.03

# %%
# hold out 100 times
array = dataset.values
X = array[:,1:30]
Y = array[:,0]
CV2 = StratifiedShuffleSplit(n_splits=100, test_size=0.3, random_state=0)

# %%
# Decision Tree using gini (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='gini')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.92
# Standard Deviation:  0.03

# %%
# Decision Tree using gini (with pruning parameter)
dt = DecisionTreeClassifier( criterion='gini', ccp_alpha=0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.92
# Standard Deviation:  0.03

# %%
# Decision Tree using Entropy (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='entropy')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.93
# Standard Deviation:  0.03

# %%
# Decision Tree using Entropy (pruning parameter)
dt= DecisionTreeClassifier( criterion='entropy', ccp_alpha= 0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.93
# Standard Deviation:  0.03

# %% [markdown]
# # DATASET 2
# ## DEATH DUE TO HEART FAILURE

# %%
data = pd.read_csv(r"D:\FastSemesters\semester5\ML\lab\heartfailure\heart_failure_clinical_records_dataset.csv")
data.replace(['?', 'NULL'], 0)
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
# 10X10 FOLD CV
array = data.values
X = array[:,0:12]
Y = array[:,12]

CV = RepeatedKFold(n_splits = 10, n_repeats = 10, random_state = 1)

# %%
# Decision Tree using gini (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='gini')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.77
# Standard Deviation:  0.07

# %%
# Decision Tree using gini (pruning parameter)
dt = DecisionTreeClassifier( criterion='gini', ccp_alpha = 0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.82
# Standard Deviation:  0.07

# %%
# Decision Tree using Entropy (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='entropy')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.78
# Standard Deviation:  0.08

# %%
# Decision Tree using Entropy (pruning parameter)
dt= DecisionTreeClassifier( criterion='entropy', ccp_alpha= 0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.79
# Standard Deviation:  0.07

# %%
# hold out 100 times
array = data.values
X = array[:,0:12]
Y = array[:,12]
CV2 = StratifiedShuffleSplit(n_splits=100, test_size=0.3, random_state=0)

# %%
# Decision Tree using gini (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='gini')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.78
# Standard Deviation:  0.07

# %%
# Decision Tree using gini (with pruning parameter)
dt = DecisionTreeClassifier( criterion='gini', ccp_alpha=0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.82
# Standard Deviation:  0.07

# %%
# Decision Tree using Entropy (with out pruning parameter)
dt = DecisionTreeClassifier( criterion='entropy')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.79
# Standard Deviation:  0.08

# %%
# Decision Tree using Entropy (pruning parameter)
dt= DecisionTreeClassifier( criterion='entropy', ccp_alpha= 0.015)
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.79
# Standard Deviation:  0.08

# %%
# Decision Roots using Enthalpy (with out pruning parameter)
dt = DecisionTreeClassifier( criterion= 'entropy')
Acc_n_Std = cross_val_score(dt, X, Y, scoring='accuracy', cv=CV, n_jobs = -1)
print('Accuracy: ', round(np.mean(Acc_n_Std),2))
print('Standard Deviation: ',round(np.std(Acc_n_Std),2))
# Out:
# Accuracy:  0.78
# Standard Deviation:  0.08

# %% [markdown]
# # QUESTION #02

# %%
#Second task is to find out root node of decision tree from scratch on above dataset of
#(outlook, temperature, humidity, windy) using ID3 algorithm. You can create this dataset in excel
#file.

# %%
d = pd.read_excel(r"D:\FastSemesters\semester5\ML\lab\outlook.xlsx")
d
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
entropy = -(9/14)*np.log(9/14) - (5/14)*np.log(5/14)
entropySunny = -(2/5)*np.log(2/5) - (3/5)*np.log(3/5) 
entropyOvercast = -(4/4)*np.log2(4/4) - 0
entropyRainy = -(3/5)*np.log(3/5) - (2/5)*np.log(2/5) 
entropyOutcast = (5/14)*(entropySunny)+(5/14)*(entropyRainy)+(4/14)*(entropyOvercast)
print(entropyOutcast)
# Out:
# 0.48072261929232607

# %%
print(entropy)
# Out:
# 0.6517565611726531

# %%
def rootNode(Dataset):
  infogains = []
  for columns in d.columns:
    if columns != 'PlayTennis':
      infogains.append([columns,Informationgain(columns,Dataset)])
  infogains = sorted(infogains,key = lambda x:x[1],reverse = True)
  print("Root Node:",infogains[0][0])

def Informationgain(column,DataSet):
  values = DataSet[column]
  totalvalues = values.unique()
  values = list(DataSet[column])
  entropy = 0
  for a in totalvalues:
    entropy -= (values.count(a)/len(values)) * math.log2((values.count(a)/len(values)))
  return entropy

rootNode(d)
# Out:
# Root Node: outlook
