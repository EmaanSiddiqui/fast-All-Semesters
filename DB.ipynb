# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\FastSemesters\semester5\DB\project\imdb_top_1000.csv")
data
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
dataset = pd.read_csv(r"D:\FastSemesters\semester5\DB\project\imdb_top_1000.csv")
dataset.drop(labels=['Certificate','Meta_score'],axis=1,inplace=True)

# %%
dataset.drop(labels=['No_of_Votes','Gross'],axis=1,inplace=True)

# %%
dataset
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# ...

# %%
dataset.head(10)
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5  https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6  https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7  https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 8  https://m.media-amazon.com/images/M/MV5BMjAxMz...
# 9  https://m.media-amazon.com/images/M/MV5BMmEzNT...
#
#                                     Series_Title Released_Year  Runtime  \
# 0                       The Shawshank Redemption          1994  142 min
# 1                                  The Godfather          1972  175 min
# 2                                The Dark Knight          2008  152 min
# 3                         The Godfather: Part II          1974  202 min
# ...

# %%
dataset.tail(10)
# Out:
#                                            Poster_Link  \
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 993  https://m.media-amazon.com/images/M/MV5BYTE4YW...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year  Runtime  \
# 990            Giù la testa          1971  157 min
# 991          Kelly's Heroes          1970  144 min
# 992         The Jungle Book          1967   78 min
# 993                  Blowup          1966  111 min
# 994      A Hard Day's Night          1964   87 min
# ...

# %%
result_DataFrame = dataset.loc[dataset['IMDB_Rating'] > 7.6]
result_DataFrame
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 872  https://m.media-amazon.com/images/M/MV5BMTU5NT...
# 873  https://m.media-amazon.com/images/M/MV5BYzM3Yj...
# 874  https://m.media-amazon.com/images/M/MV5BYWUxMz...
# 875  https://m.media-amazon.com/images/M/MV5BMjAxMT...
# 876  https://m.media-amazon.com/images/M/MV5BYjllMm...
#
#                       Series_Title Released_Year  Runtime  \
# 0         The Shawshank Redemption          1994  142 min
# 1                    The Godfather          1972  175 min
# 2                  The Dark Knight          2008  152 min
# 3           The Godfather: Part II          1974  202 min
# ...
