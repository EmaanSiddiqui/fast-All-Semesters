# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %%
#from pandas.core.frame import DataFrame
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
data= pd.read_csv(r"D:\FastSemesters\semster4\AI\lab_Final\dataset\iris.data", names=names)
#data['class'].replace({'Iris-setosa':0,'Iris-virginica':1,'Iris-versicolor':2 },inplace= True)
#df= data.values
#x = df[:,0:4]
#y = df[:, 4]
x = data.drop(columns="class")

y = data["class"]

feature_names = x.columns

labels = y.unique()
#y=y.astype('int')

# %%
x_train,  x_test, y_train, y_test = train_test_split(x, y,
                                                    test_size = 0.4,
                                                    random_state = 42)

# %%
dt = DecisionTreeClassifier( criterion='entropy', ccp_alpha = 0.015) # ccp_alpha is pruning parameter
dt.fit(x_train, y_train)      # training the model
predictions = dt.predict(x_test)  # now testing on test data to get class of test data
print((accuracy_score(y_test, predictions))) # comparing results predicted by model with actual to get accuracy scor
# Out:
# 0.9833333333333333

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(max_depth =4, random_state = 42)

clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=42)

# %%
from sklearn import tree

import matplotlib.pyplot as plt

plt.figure(figsize=(30,10), facecolor ='w')

a = tree.plot_tree(clf,

                   feature_names = feature_names,

                   class_names = labels,

                   rounded = True,

                   filled = True,

                   fontsize=14)

plt.show()
